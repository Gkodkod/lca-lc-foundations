# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain_groq import ChatGroq

model = init_chat_model(
    "llama-3.3-70b-versatile",
    model_provider="groq",
    temperature=1.0,
)

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='37e5f506-0204-4198-b18e-7a368586712c'),
#               AIMessage(content="Hello Seán! It's great to meet you. Green is a wonderful colour, don't you think? It's the colour of nature, calming and refreshing. What do you like most about the colour green? Is it the way it looks in landscapes, or do you have a favourite green item, like a shirt or a pair of shoes?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 71, 'prompt_tokens': 47, 'total_tokens': 118, 'completion_time': 0.228096713, 'completion_tokens_details': None, 'prompt_time': 0.001497679, 'prompt_tokens_details': None, 'queue_time': 0.135400212, 'total_time': 0.229594392}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f3989-545d-7630-a538-a638811add49-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 71, 'total_tokens': 118})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='991d732c-dd3b-406a-80cf-2b1ab0bc182f'),
#               AIMessage(content="I don't have any information about your favorite color. This is the start of our conversation, and I don't have any prior knowledge about your personal preferences. Would you like to share your favorite color with me?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 41, 'total_tokens': 85, 'completion_time': 0.127410201, 'completion_tokens_details': None, 'prompt_time': 0.001993519, 'prompt_tokens_details': None, 'queue_time': 0.145224199, 'total_time': 0.12940372}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f3989-b77f-7992-9b2a-547e02f96c1a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 44, 'total_tokens': 85})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='d4d27849-903a-4dd6-91c7-05310fa3cf00'),
#               AIMessage(content="Hello Seán, it's lovely to meet you. Green is a great choice of favourite colour - it's a calming and natural colour that's all around us in nature. What do you like most about the colour green, is it the way it looks in landscapes, the symbolism it has in different cultures, or something else entirely?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 68, 'prompt_tokens': 47, 'total_tokens': 115, 'completion_time': 0.229908082, 'completion_tokens_details': None, 'prompt_time': 0.007139401, 'prompt_tokens_details': None, 'queue_time': 0.03737403, 'total_time': 0.237047483}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f3989-fe14-7e63-8b6d-f6103fa100d0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 68, 'total_tokens': 115})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='d4d27849-903a-4dd6-91c7-05310fa3cf00'),
#               AIMessage(content="Hello Seán, it's lovely to meet you. Green is a great choice of favourite colour - it's a calming and natural colour that's all around us in nature. What do you like most about the colour green, is it the way it looks in landscapes, the symbolism it has in different cultures, or something else entirely?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 68, 'prompt_tokens': 47, 'total_tokens': 115, 'completion_time': 0.229908082, 'completion_tokens_details': None, 'prompt_time': 0.007139401, 'prompt_tokens_details': None, 'queue_time': 0.03737403, 'total_time': 0.237047483}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f3989-fe14-7e63-8b6d-f6103fa100d0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 68, 'total_tokens': 115}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='f587f7ca-0bbc-4ca4-9619-5fd6ffd241b2'),
#               AIMessage(content='You told me your favourite colour is green, Seán!', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 130, 'total_tokens': 143, 'completion_time': 0.061446238, 'completion_tokens_details': None, 'prompt_time': 0.00787553, 'prompt_tokens_details': None, 'queue_time': 0.206215218, 'total_time': 0.069321768}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f398a-2809-75c1-9044-0a1ddfeb9610-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 130, 'output_tokens': 13, 'total_tokens': 143})]}
