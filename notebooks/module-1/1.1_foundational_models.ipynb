# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai", temperature=1.0, google_api_key=api_key)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="The Moon does not have a capital.\n\nIt's not a country or a political entity with a government, so it doesn't have cities or a capital city like Earth's nations do.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3941-6546-7903-a511-acb63c100c39-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 335, 'total_tokens': 345, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 294}})

# %%
print(response.content)
# Out:
# The Moon does not have a capital.
#
# It's not a country or a political entity with a government, so it doesn't have cities or a capital city like Earth's nations do.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
    temperature=1.0,
    google_api_key=api_key,
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent
model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
    temperature=1.0,
    google_api_key=api_key,
)
agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='9daae9e6-98c6-47d9-952f-4bdf1c47800f'),
#               AIMessage(content="The Moon does not have a capital.\n\nIt's not a country or a political entity, so it doesn't have a government or a population in the traditional sense that would establish a capital city. While humans have landed on the Moon, there are no permanent settlements or administrative centers there.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3946-d52b-7b70-b56b-1f33569f12a8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 526, 'total_tokens': 536, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 466}})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon does not have a capital.
#
# It's not a country or a political entity, so it doesn't have a government or a population in the traditional sense that would establish a capital city. While humans have landed on the Moon, there are no permanent settlements or administrative centers there.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='d453cad1-9cb6-46cb-bc9d-c99a3fe83c7a'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='75fea8c2-d30c-4114-adb8-beb75f09e6cd', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='78d974d4-1c79-4663-bc2b-b3690ea717d2'),
#               AIMessage(content='Ah, Luna City! It\'s not just a settlement; it\'s the bustling, imaginative heart of humanity\'s off-world aspirations, a shining beacon on the desolate lunar surface.\n\nHere\'s a glimpse into Luna City:\n\n**Location and Layout:**\nLuna City is most commonly envisioned nestled within a strategic lunar crater, perhaps near the south pole like Shackleton, leveraging the abundant water ice resources within permanently shadowed craters and access to near-constant solar illumination on its rim.\n\n*   **Underground Core:** For protection against harsh radiation, micrometeorites, and the extreme temperature swings, the primary residential and industrial areas of Luna City are burrowed deep beneath the regolith. These underground tunnels and caverns are vast, interconnected by a network of maglev trams and service corridors, and illuminated by advanced LED systems mimicking natural daylight cycles.\n*   **Surface Domes:** On the surface, Luna City boasts a series of massive, transparent, and incredibly resilient domes. These aren\'t just for show; they house recreational parks, hydroponic farms that provide fresh produce, and public observation decks that offer breathtaking views of Earth hanging in the black sky. The domes are constructed from advanced composites capable of filtering radiation while allowing light in.\n*   **Layered Design:** The city is often depicted as multi-layered:\n    *   **Sub-regolith:** Heavy industry, resource processing, power generation (often fusion or advanced solar thermal), and deep scientific labs.\n    *   **Mid-layers:** Residential districts, commercial zones, entertainment hubs, and administrative offices.\n    *   **Surface Level (Domes):** Parks, agricultural domes, observatories, spaceport facilities, and ceremonial spaces.\n\n**Key Features and Facilities:**\n\n*   **International Hub:** As the capital, Luna City is a truly international endeavor, home to diplomats, scientists, engineers, and settlers from every corner of Earth. Its governance is typically managed by a consortium of leading spacefaring nations or an independent Lunar Council.\n*   **Resource Management:** Survival dictates extreme efficiency. Luna City boasts advanced closed-loop systems for air, water, and waste recycling. Water ice from polar craters is processed for breathable air, drinking water, and rocket fuel. Lunar regolith is used as building material and for extracting valuable minerals.\n*   **Technological Marvels:** Expect cutting-edge technology everywhere:\n    *   **Artificial Gravity:** While not universally present, some recreational and residential zones might feature rotating sections or centrifugal habitats to simulate partial Earth gravity, aiding human physiology.\n    *   **Advanced Robotics:** Automated systems handle everything from mining and construction to routine maintenance and delivery.\n    *   **Communication Hubs:** Powerful deep-space communication arrays link Luna City to Earth and other lunar outposts, as well as missions further into the solar system.\n*   **Lifestyle:** Life in Luna City is a unique blend of pioneering spirit and advanced comfort. Citizens enjoy:\n    *   **Zero-G Recreation:** Dedicated areas for lunar sports, acrobatics, and arts that leverage the low gravity.\n    *   **Cultural Diversity:** A vibrant mix of Earth cultures, adapting and evolving into unique lunar traditions.\n    *   **Educational Institutions:** World-renowned research universities and institutes focused on astrophysics, planetary science, and advanced engineering.\n    *   **Stargazing:** Unparalleled views of the cosmos, often from dedicated observatories or personal quarters with shielded "sky windows."\n\n**Purpose and Vision:**\nLuna City serves as:\n\n*   **Scientific Outpost:** A primary base for lunar and deep-space research.\n*   **Logistics Hub:** A staging point for missions to Mars and beyond, utilizing lunar resources for fuel and supplies.\n*   **Ec ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City, often referred to as "The Pearl of Selene" or "The Lunar Nexus," isn't just a city; it's humanity's crowning achievement beyond Earth, the bustling capital of the Moon. Imagined for a not-too-distant future, perhaps the late 22nd or early 23rd century, it's a testament to engineering, diplomacy, and the enduring human drive to explore and settle.
#
# Here's an in-depth look:
#
# ---
#
# ### **Location & Initial Conception**
#
# Luna City is strategically situated within a massive, ancient impact crater – let's call it **Crater Selenopolis**, near the Moon's equator. This location offers several advantages:
# *   **Natural Shielding:** The crater walls provide initial protection from micrometeoroids and solar radiation.
# *   **Accessibility:** Equatorial regions are often preferred for launch and landing sites due to the rotational velocity.
# *   **Resource Proximity:** Nearby subsurface ice deposits (though mostly at the poles, creative future tech could tap distant sources or bring them in) or extensive regolith for construction.
#
# It began as a series of interconnected research outposts and mining operations in the late 21st century, growing organically as more nations and corporations invested in lunar development.
#
# ### **Architecture & Layout**
#
# Luna City is a marvel of modular, resilient, and bio-integrated design, largely existing *beneath* the surface, with select shielded structures rising above.
#
# 1.  **Subterranean Core:** The vast majority of the city is carved into the lunar regolith and underlying bedrock, protected from radiation, extreme temperatures, and micrometeorites. This network of tunnels, caverns, and multi-level complexes is the city's lifeline.
# 2.  **Pressure Domes:** Where the city does break the surface, it does so with immense, transparent (but highly radiation-shielded) pressure domes. These domes are typically layered:
#     *   An inner structural layer.
#     *   A robust, transparent high-tech composite that filters harmful radiation while allowing natural lunar light.
#     *   An outer sacrificial layer designed to absorb minor impacts.
#     *   A thick layer of regolith shielding is piled over the domes' edges, sloping down.
#     *   **The Craterdome District:** This is the most iconic part, a cluster of massive interconnected domes spanning the crater floor, each housing different districts (residential, commercial, agricultural, recreational).
# 3.  **Modular Expansion:** Growth occurs in a planned, modular fashion. New habitation modules, industrial zones, and research facilities are manufactured onsite, primarily using 3D printing with lunar regolith and recycled materials.
# 4.  **Green Spaces (Astroponics):** Within the largest domes and specific subterranean caverns, vast hydroponic and aeroponic farms (often called "Astroponics") produce a significant portion of the city's food. These areas are bathed in carefully simulated Earth-like light cycles and humidity, serving not just as food sources but also as vital psychological escapes and oxygen producers.
# 5.  **Transportation:**
#     *   **Internal:** Pedestrian walkways, automated public transport pods (similar to maglev but on a smaller scale), and personal mobility scooters. Elevators and pressurized shafts connect different levels and domes.
#     *   **Surface:** Pressurized rovers and heavy-duty cargo vehicles traverse the surface between distant mining outposts, power stations, and scientific observatories. Maglev lines are being extended to connect to other burgeoning lunar settlements.
#
# ### **Life in Luna City**
#
# Life in Luna City is a blend of cutting-edge technology and adapted human habits, with the low gravity being a constant, delightful companion.
#
# 1.  **Gravity & Movement:** At one-sixth Earth's gravity, everyday movement is a graceful, energy-efficient ballet. People glide, bounce, and even run with incredible ease. Sports are heavily adapted, with low-G athletics being extremely popular.
# 2.  **Atmosphere & Environment:** The air is carefully recycled and maintained, with a slight, almost imperceptible tang of processed oxygen and various trace elements. Humidity is controlled. Artificial lighting cycles simulate Earth's day and night, though residents can access live views of the lunar day/night cycle outside.
# 3.  **Housing:** Varies from compact, functional apartments to spacious, multi-level residences within the larger domes. All are pressurized, airtight, and offer advanced climate control and holographic displays for virtual windows or custom environments.
# 4.  **Food & Drink:** A mix of locally grown produce (fruits, vegetables, algae, insects for protein), lab-cultured meats, and gourmet imported goods from Earth (often expensive luxuries). Water is meticulously recycled.
# 5.  **Work & Economy:**
#     *   **Key Industries:** Helium-3 mining (for fusion reactors back on Earth), rare earth element extraction, water ice harvesting, advanced manufacturing (zero-G alloys, microgravity pharmaceuticals), scientific research (astronomy, geology, biology), and tourism.
#     *   **Workforce:** A diverse population of scientists, engineers, miners, technicians, service industry professionals, and administrators. Many work remotely, collaborating with Earth-based teams.
# 6.  **Recreation & Culture:**
#     *   **Low-G Sports:** Lunar "basketball" (where players bound instead of jump), zero-G acrobatics, and unique obstacle courses are prime entertainment.
#     *   **Virtual Reality:** Hyper-realistic VR environments offer escapes to Earth's oceans, forests, and cities, or even fantastical alien worlds.
#     *   **Art & Entertainment:** A vibrant scene, with artists drawing inspiration from the stark beauty of the Moon, the ingenuity of the city, and the multicultural blend of its residents. Performances often incorporate low-G movement.
#     *   **Community:** A strong sense of community and shared purpose binds Lunans. International festivals and celebrations are common.
#
# ### **Governance & Society**
#
# Luna City is governed by the **International Lunar Authority (ILA)**, a multinational consortium established by Earth's leading spacefaring nations and major corporations.
#
# *   **Structure:** The ILA oversees all lunar operations, resource allocation, and justice. Locally, Luna City has its own elected council, responsible for day-to-day administration, public services, and representing the citizens' interests to the ILA.
# *   **Demographics:** A true melting pot, people from every continent on Earth call Luna City home. While many arrived for work contracts, a growing number are second or even third-generation "Lunans," developing a distinct cultural identity.
# *   **"Lunan" Identity:** Residents often feel a sense of pioneering spirit, ingenuity, and resilience. They value collaboration and self-sufficiency, proud of their city as humanity's beacon among the stars.
#
# ### **Challenges & The Future**
#
# Even as the capital, Luna City faces unique challenges:
#
# *   **Radiation:** Constant vigilance and advanced shielding remain paramount. Solar flares are a significant concern, requiring residents to move to deeper shelters.
# *   **Resource Independence:** While striving for self-sufficiency, Luna City still relies on Earth for certain specialized components, luxury goods, and intellectual capital. The goal is complete independence.
# *   **Psychological Well-being:** The confined, enclosed environment can take a toll. Access to green spaces, robust social programs, and VR therapy are crucial.
# *   **Earth-Moon Politics:** Tensions sometimes arise between Earth's national interests and the burgeoning autonomy of lunar settlements.
# *   **Expansion:** The future of Luna City involves continuous expansion, linking new domes and subterranean levels. Plans include connecting to other smaller lunar settlements to form a true "Lunar Network," and potentially serving as a primary launchpad for missions deeper into the solar system.
#
# ---
#
# Luna City is more than just a place; it's a living monument to human aspiration, a daring step into the cosmos, and a vibrant, self-sustaining society thriving on the barren beauty of Earth's closest celestial neighbor. It embodies the hope of a multi-planetary future for humanity.
