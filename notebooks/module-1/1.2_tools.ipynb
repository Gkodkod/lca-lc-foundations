# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai", temperature=1.0, google_api_key=api_key)

agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='cb9778b7-1462-4789-bc13-d3f2c973adc9'),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'square_root', 'arguments': '{"x": 467}'}, '__gemini_function_call_thought_signatures__': {'ad3bddd0-e367-412f-aec0-87e8e7e910d5': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3953-3af6-7852-9012-790a896b59d3-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'ad3bddd0-e367-412f-aec0-87e8e7e910d5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 71, 'output_tokens': 87, 'total_tokens': 158, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 70}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='62348c49-e018-4602-8fc2-908f55606fdb', tool_call_id='ad3bddd0-e367-412f-aec0-87e8e7e910d5'),
#  AIMessage(content='The square root of 467 is approximately 21.61.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3953-3e7d-7383-ac2b-b4cd179b311b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 119, 'output_tokens': 17, 'total_tokens': 136, 'input_token_details': {'cache_read': 0}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'ad3bddd0-e367-412f-aec0-87e8e7e910d5', 'type': 'tool_call'}]
