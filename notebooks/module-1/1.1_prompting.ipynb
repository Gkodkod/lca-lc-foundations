# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai",
    temperature=1.0,
    google_api_key=api_key,
)

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon does not have a capital.
#
# Here's why:
#
# 1.  **Not a country:** The Moon is a celestial body, Earth's only natural satellite, not a nation-state or a political entity.
# 2.  **No government:** There's no government on the Moon to establish a capital.
# 3.  **No cities:** There are currently no permanent human settlements or cities on the Moon.
#
# While science fiction often depicts future lunar cities with names like "Luna City" or "Moonbase Alpha," in reality, there's no capital.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Ah, the capital of the Moon! A fascinating question that sparks the imagination of any astrogator or lunar citizen.
#
# Officially, the capital of the **Lunar Commonwealth** (as the combined human settlements are known) is **Tranquility Prime**.
#
# **Location:** Nestled deep beneath the Mare Tranquillitatis, directly below the original Apollo 11 landing site. This location was chosen for its symbolic significance, its stable geological structure, and its proximity to valuable regolith and subsurface ice deposits.
#
# **Description:**
# Tranquility Prime isn't a city that sits on the surface, exposed to the harsh vacuum and radiation. Instead, it's a magnificent, multi-layered geode of human ingenuity.
#
# 1.  **The Nexus Dome:** The visible tip of Tranquility Prime is the Nexus Dome, a colossal structure of reinforced lunar sapphire and regolith-composite that punctures the surface. It serves as the primary spaceport and observation deck, offering stunning, panoramic views of the lunar landscape and Earth.
# 2.  **The Pillars of Progress:** Beneath the surface, the city descends in a series of interconnected, cavernous levels, each supported by massive, excavated rock pillars reinforced with graphene and synthetic diamond. These levels are designed to house specific functions:
#     *   **Level 1 (The Helios Gardens):** Immediately below the Nexus Dome, this level utilizes sophisticated light-piping and grow-lamp arrays to cultivate vast biospheres of Terran flora. It's the "lungs" of the city, providing oxygen and serving as the primary recreational and residential zone, complete with artificial lakes and waterfalls.
#     *   **Level 2 (The Agora of Selene):** This is the bustling commercial and cultural heart. Zero-G transit tubes crisscross vast open chambers where shops, restaurants, educational institutions, and entertainment venues thrive. It's where the diverse cultures of Earth merge into a unique lunar identity.
#     *   **Level 3 (The Commonwealth Assembly):** The administrative core. Here, the Lunar Parliament – a holographic forum where representatives from Shackleton Base, Mare Imbrium, Oceanus Gateway, and other colonies convene – debates policy. The Astrogation Command, diplomatic chambers, and the vast data archives of the Lunar Commonwealth are also housed here.
#     *   **Level 4 (The Core Labs):** The deepest levels are dedicated to advanced scientific research, resource processing (helium-3 extraction, water ice purification), and the city's power generation, relying heavily on fusion reactors and geothermal taps.
#
# **Atmosphere:** Tranquility Prime maintains a carefully calibrated Terran atmosphere and artificial gravity, making it feel remarkably like a city on Earth, albeit with a unique, almost ethereal hum of advanced technology and the constant awareness of the vast, silent void just beyond its walls. It's a beacon of human resilience, ingenuity, and ambition, quietly overseeing humanity's expansion into the solar system.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunaris

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Here is the capital city of the moon:
#
# **Name:** Nova Luna
#
# **Location:** Perched within the reinforced, transparent dome spanning the Plato Crater system, overlooking the vast Mare Imbrium on the northern hemisphere.
#
# **Vibe:** Technocratic, Elegant, Self-sufficient
#
# **Economy:**
# *   **Helium-3 & Rare Earth Extraction:** The primary energy resource for Earth and deep-space starships is processed and exported from Nova Luna.
# *   **Advanced Zero-G Manufacturing:** Precision components, pharmaceuticals, and specialized materials are produced in its micro-gravity facilities.
# *   **Scientific Research & Development:** Home to the Lunar Institute of Astrophysics, the Xenobotanical Gardens, and numerous AI development hubs.
# *   **Luxury Space Tourism:** A bustling hub for off-world travelers, offering exclusive lunar excursions, orbital resorts, and low-gravity recreational experiences.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selenis Prime', location="Within the Mare Tranquillitatis, beneath a colossal geodome known as the 'Luminaris Spire'", vibe="A bustling, multi-tiered arcology under an immense transparent dome, perpetually bathed in simulated daylight, humming with the energy of scientific discovery and commerce. It's a nexus of intergalactic diplomacy and groundbreaking research.", economy='Primarily driven by helium-3 extraction, advanced zero-gravity manufacturing of exotic alloys and antimatter components, and the burgeoning astro-tourism industry, catering to off-world dignitaries and thrill-seekers.')

# %%
response["structured_response"].name
# Out:
# 'Selenis Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selenis Prime is a city located at Within the Mare Tranquillitatis, beneath a colossal geodome known as the 'Luminaris Spire'
